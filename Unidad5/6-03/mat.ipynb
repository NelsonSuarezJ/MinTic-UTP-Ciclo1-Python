# %%
# pip install matplotlib
# pip install seaborn 
import seaborn as sns
import pandas as pd
import matplotlib.pyplot as plt

fig, ax =plt.subplots(ncols=2,figsize=(10,4))

dataDevs=pd.read_csv('devsEncsv.csv')
sns.pointplot(x='salario',y='years',data=dataDevs,ax=ax[0])
sns.pointplot(x='years',y='salario',data=dataDevs,ax=ax[1])
# Out:
# <AxesSubplot:xlabel='years', ylabel='salario'>
